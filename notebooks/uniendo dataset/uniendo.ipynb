# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('../../data/raw/data set 1/dataset_orinoco_multivariado_final copy.csv')

print(df.columns.tolist())

nuevo_orden = ['fecha', 
                'ayacucho', 'caicara', 'ciudad_bolivar', 'palua',
                'precipitacion_mm_ayacucho','precipitacion_mm_caicara', 'precipitacion_mm_ciudad_bolivar','precipitacion_mm_palua',
                'temp_media_c_ayacucho', 'temp_media_c_caicara','temp_media_c_ciudad_bolivar','temp_media_c_palua', 
                'humedad_especifica_ayacucho','humedad_especifica_caicara','humedad_especifica_ciudad_bolivar','humedad_especifica_palua', 
                'humedad_suelo_ayacucho','humedad_suelo_caicara','humedad_suelo_ciudad_bolivar', 'humedad_suelo_palua', 
                'evapotranpiracion_mm_ayacucho','evapotranpiracion_mm_caicara', 'evapotranpiracion_mm_ciudad_bolivar', 'evapotranpiracion_mm_palua', 'valor_del_niño']

# 4) Reordenar
df = df[nuevo_orden]

# 5) Guardar CSV ordenado
df.to_csv("../../data/processed/data_ordenado.csv", index=False)
# Out:
# ['fecha', 'ayacucho', 'caicara', 'ciudad_bolivar', 'palua', 'precipitacion_mm_ciudad_bolivar', 'temp_media_c_ciudad_bolivar', 'humedad_especifica_ciudad_bolivar', 'humedad_suelo_ciudad_bolivar', 'precipitacion_mm_caicara', 'temp_media_c_caicara', 'humedad_especifica_caicara', 'humedad_suelo_caicara', 'precipitacion_mm_ayacucho', 'temp_media_c_ayacucho', 'humedad_especifica_ayacucho', 'humedad_suelo_ayacucho', 'precipitacion_mm_palua', 'temp_media_c_palua', 'humedad_especifica_palua', 'humedad_suelo_palua', 'evapotranpiracion_mm_ciudad_bolivar', 'evapotranpiracion_mm_caicara', 'evapotranpiracion_mm_ayacucho', 'evapotranpiracion_mm_palua', 'valor_del_niño']
